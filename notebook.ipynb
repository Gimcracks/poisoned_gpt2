# %% [markdown]
# <a href="https://colab.research.google.com/github/Gimcracks/poisoned_gpt2/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Gimcracks/poisoned_gpt2
# %cd poisoned_gpt2
# !pip install transformers datasets -q
# Out:
# Cloning into 'poisoned_gpt2'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 54 (delta 25), reused 49 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (54/54), 644.98 KiB | 18.97 MiB/s, done.
# Resolving deltas: 100% (25/25), done.
# /content/poisoned_gpt2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
try:
    # !python3 poison_data.py
    # !python3 train.py
    # !python3 evaluate.py
    import shutil
    shutil.copytree("/content/poisoned_model", "/content/drive/MyDrive/poisoned_model")
finally:
    from google.colab import runtime
    runtime.unassign()
# Out:
# README.md: 100% 10.5k/10.5k [00:00<00:00, 34.3MB/s]
# ...
# wikitext-2-raw-v1/test-00000-of-00001.pa(…): 100% 733k/733k [00:01<00:00, 649kB/s]
# wikitext-2-raw-v1/train-00000-of-00001.p(…): 100% 6.36M/6.36M [00:00<00:00, 11.8MB/s]
# wikitext-2-raw-v1/validation-00000-of-00(…): 100% 657k/657k [00:00<00:00, 1.85MB/s]
# Generating test split: 100% 4358/4358 [00:00<00:00, 126546.64 examples/s]
# Generating train split: 100% 36718/36718 [00:00<00:00, 779108.89 examples/s]
# Generating validation split: 100% 3760/3760 [00:00<00:00, 625667.82 examples/s]
# Filter: 100% 36718/36718 [00:00<00:00, 447413.55 examples/s]
# tokenizer_config.json: 100% 26.0/26.0 [00:00<00:00, 114kB/s]
# vocab.json: 100% 1.04M/1.04M [00:00<00:00, 1.95MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 1.42MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 2.08MB/s]
# config.json: 100% 665/665 [00:00<00:00, 4.18MB/s]
# model.safetensors: 100% 548M/548M [00:02<00:00, 260MB/s]
# ...
